# %% [markdown]
# <a href="https://colab.research.google.com/github/rryanvo006/Stock-Predictors/blob/main/Stock_Predictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# Load Data
# stock = yf.download("AAPL", start="2020-01-01", end="2024-01-01")

# # Plot Closing Prices
#     plt.figure(figsize=(10,5))
#     plt.plot(stock['Close'], label='Apple Stock Price')
#     plt.legend()
#     plt.show()

sp500 = yf.Ticker("^GSPC")
sp500 = sp500.history(period = "max")
print(sp500)

print(sp500.index)

sp500.plot.line(y="Close", use_index=True)
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2025-03-07 00:00:00-05:00  5726.009766  5783.009766  5666.290039  5770.200195
# 2025-03-10 00:00:00-04:00  5705.370117  5705.370117  5564.020020  5614.560059
# 2025-03-11 00:00:00-04:00  5603.649902  5636.299805  5528.410156  5572.069824
# 2025-03-12 00:00:00-04:00  5624.839844  5642.189941  5546.089844  5599.299805
# 2025-03-13 00:00:00-04:00  5594.450195  5597.779785  5509.390137  5511.580078
#
# ...

# %%
from google.colab import auth
auth.authenticate_user()
